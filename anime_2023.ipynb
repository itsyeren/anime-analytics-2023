# %% [markdown]
# <a href="https://colab.research.google.com/github/itsyeren/anime-analytics-2023/blob/main/anime_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery

client = bigquery.Client(project="anime-2023-478915")

# %%
from google.cloud import bigquery

client = bigquery.Client(project="anime-2023-478915")
print("Project on client:", client.project)
# Out:
# Project on client: anime-2023-478915

# %%
list(client.list_datasets())

# %%
df_general = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.anime_general_cleaned`
    LIMIT 5
""").to_dataframe()

df_general.head()
# Out:
#    anime_id                           title  user_id        username  \
# 0     32383  Osomatsu-san Short Film Series   565739          ned993
# 1     32383  Osomatsu-san Short Film Series   970301     Etsu_Hikaru
# 2     32383  Osomatsu-san Short Film Series  4192599       Lionax736
# 3     36775            Wo Shi Jiang Xiaobai  1039405         Cogibbt
# 4     36775            Wo Shi Jiang Xiaobai  5213640  MK_TRUTHSEEKER
#
#    my_score  score  scored_by  popularity  rank  \
# 0         6   6.66       1313        5141  4940
# 1         7   6.66       1313        5141  4940
# 2         6   6.66       1313        5141  4940
# 3         0   7.26        361        6297  2595
# 4         9   7.26        361        6297  2595
#
#                            genre     type    source  start_year licensors  \
# 0                 Comedy, Parody  Special     Manga        2016   Unknown
# 1                 Comedy, Parody  Special     Manga        2016   Unknown
# ...

# %%
df_website = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.anime_website_details`
    LIMIT 5
""").to_dataframe()

df_website.head()
# Out:
#    anime_id                                               name  score  \
# 0      3886  Super Mario Brothers: Peach-hime Kyuushutsu Da...   5.63
# 1     20587                                    Ashinaga Ojisan   5.71
# 2      2119            Captain Tsubasa: Ayaushi! Zen Nihon Jr.   6.75
# 3     22649                     Kero Kero Keroppi no Sanjuushi   6.51
# 4     33980                Mirai ni Mukete: Bousai wo Kangaeru   6.51
#
#       type duration        rating  ranked  popularity  members  favorites  \
# 0    Movie    1 hr.  G - All Ages    9351        7186     3868         16
# 1  Special    1 hr.  G - All Ages    9119       11460      659          1
# 2    Movie    1 hr.  G - All Ages    4660        7052     4067          4
# 3    Movie    1 hr.  G - All Ages   14965       14854      201          0
# 4    Movie    1 hr.  G - All Ages   15590       14248      240          0
#
#    watching  completed  on_hold  dropped
# 0        62       2697       37       82
# ...

# %%
df_score = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.score_details`
    LIMIT 5
""").to_dataframe()

df_score.head()
# Out:
#    user_id      username  anime_id  anime_title  rating  score type  ranked
# 0  1086295  Kayla_Fowler       203  Words Worth       6   6.75  OVA    <NA>
# 1   112094       Ferrero       203  Words Worth       4   6.75  OVA    <NA>
# 2  1232985     Steedster       203  Words Worth       6   6.75  OVA    <NA>
# 3   305418         Oruga       203  Words Worth       7   6.75  OVA    <NA>
# 4     2094       Trinpie       203  Words Worth       7   6.75  OVA    <NA>

# %%
df_users = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.users_details_cleaned`
    LIMIT 5
""").to_dataframe()

df_users.head()
# Out:
#      username genders date_of_birth location date_of_join  days_watched  \
# 0   FaithFury    None           NaT     None   2007-03-10          <NA>
# 1       Rydia    None    1986-03-20    Texas   2007-03-22          <NA>
# 2   kohaku___    None           NaT     None   2007-04-10          <NA>
# 3  Raakanassu    None           NaT     None   2007-04-11          <NA>
# 4   kenmanyak    None           NaT     None   2007-04-15          <NA>
#
#    completed  dropped  on_hold  in_watchlist  total_entries  rewatched  \
# 0          0        0     <NA>          <NA>           <NA>          0
# 1          0        0     <NA>          <NA>           <NA>          0
# 2          0        0     <NA>          <NA>           <NA>          0
# 3          0        0     <NA>          <NA>           <NA>          0
# 4          0        0     <NA>          <NA>           <NA>          0
#
#    episodes_watched
# 0              <NA>
# 1              <NA>
# 2              <NA>
# ...

# %%
df_genre = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.anime_genre_summary`
    LIMIT 5
""").to_dataframe()

df_genre.head()
# Out:
#      genre type  anime_count avg_score  avg_scored_by  avg_popularity
# 0   Comedy   TV     12290932      7.63         137315             831
# 1   Action   TV      9925721      7.65         181745             676
# 2  Romance   TV      7976367      7.54         133988             698
# 3    Drama   TV      6958637      7.81         154824             798
# 4   School   TV      6716266      7.56         146336             645

# %%
df_rank = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.anime_rank_bands`
    LIMIT 5
""").to_dataframe()

df_rank.head()
# Out:
#       rank_band  anime_count avg_score  avg_scored_by
# 0    01_top_100      2289271      8.77         305508
# 1    02_101_500      6372118      8.27         188765
# 2   03_501_1000      5228979      7.88         142667
# 3  04_1001_5000     17256781      7.29          66648
# 4  05_5001_plus      3397461      6.16          20269

# %%
df_year = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.anime_year_summary`
    LIMIT 5
""").to_dataframe()

df_year.head()
# Out:
#    start_year   type  anime_count avg_score  avg_scored_by
# 0        1917  Movie          611      5.71           1780
# 1        1918  Movie          228      4.73            532
# 2        1929  Movie          682      5.78            842
# 3        1930  Movie          339      5.06            720
# 4        1931  Movie          463      5.00            488

# %%
df_activity = client.query("""
    SELECT *
    FROM `anime-2023-478915.anime_dataset.user_activity_summary`
    LIMIT 5
""").to_dataframe()

df_activity.head()
# Out:
#    user_id       username  rating_count avg_user_rating
# 0     6140      trafagibr          2986            7.15
# 1    97561         Furrek          2890            6.55
# 2    65697  ArcherEmiya24          2885            7.80
# 3     2276          Sitha          2868            7.58
# 4   520489          mardi          2863            7.09
